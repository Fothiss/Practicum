# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Евгений, привет!👋</b>
#
# Меня зовут Кирилл Васильев, я буду ревьюером твоего проекта. Я предлагаю общаться на «ты», но если привычнее на «вы», просто скажи об этом!
#
# Я буду оставлять комментарии в твоем проекте. Пожалуйста, не удаляй их, они могут быть полезны в случае повторной проверки.
#
# Свои комментарии я буду обозначать <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В случае, если решение на отдельном шаге является полностью правильным. Здесь же я могу давать советы и предложения.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
# <br/>
# <div class="alert alert-info">
# Рекомендую для твоих комментариев использовать синий или любой другой цветной фон. Я постараюсь ничего не пропустить, но если комментарии будут выделены, то это мне очень поможет!
# </div>
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самостоятельно найти и исправить ее. На реальной работе твой руководитель будет поступать также. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку.

# %% [markdown]
# # Исследование молочного хозяйства
#
# В данном проекте необходимо провести исследование и создать прогнозные модели для отбора коров к покупке для молочного хозяйства "Вольный луг". Его владелец планиурет закупку коров у ассоциации пастбищ "Экоферма". Критериями при выборе коровы являются:
# - средний удой в год (не менее 6000 килограммов);
# - вкус молока.
#
# **Описание данных**
#
# Данные для исследования представлены в трех датасетах:
# - `ferma_main.csv`
# - `ferma_dad.csv`
# - `cow_buy.csv`
#
#
# Файл **`ferma_main.csv`** содержит данные о стаде фермера на текущий момент.
#
# - `id` — уникальный идентификатор коровы.
# - `Удой, кг` — масса молока, которую корова даёт в год (в килограммах).
# - `ЭКЕ (Энергетическая кормовая единица)` — показатель питательности корма коровы.
# - `Сырой протеин, г` — содержание сырого протеина в корме (в граммах).
# - `CПО (Сахаро-протеиновое соотношение)` — отношение сахара к протеину в корме коровы.
# - `Порода` — порода коровы.
# - `Тип пастбища` — ландшафт лугов, на которых паслась корова.
# - `порода папы_быка` — порода папы коровы.
# - `Жирность,%` — содержание жиров в молоке (в процентах).
# - `Белок,%` — содержание белков в молоке (в процентах).
# - `Вкус молока` — оценка вкуса по личным критериям фермера, бинарный признак (вкусно, не вкусно).
# - `Возраст` — возраст коровы, бинарный признак (менее 2 лет, более 2 лет).
#
# Признаки в датасете `ferma_main.csv` можно разделить на группы.
#
# - Характеристики коровы: `id`, `Порода`, `порода папы_быка`, `Возраст`.
# - Характеристики корма: `ЭКЕ (Энергетическая кормовая единица)`, `Сырой протеин, г`, `СПО (Сахаро-протеиновое соотношение)`.
# - Характеристика пастбища: `Тип пастбища`.
# - Характеристики молока: `Удой, кг`, `Жирность,%`, `Белок,%`, `Вкус молока`.
#
# Файл **`ferma_dad.csv`** хранит имя папы каждой коровы в стаде фермера.
#
# - `id` — уникальный идентификатор коровы.
# - `Имя Папы` — имя папы коровы.
#
#
# Файл **`cow_buy.csv`** — это данные о коровах «ЭкоФермы», которых фермер хочет изучить перед покупкой.
#
# - `Порода` — порода коровы.
# - `Тип пастбища` — ландшафт лугов, на которых паслась корова.
# - `порода папы_быка` — порода папы коровы.
# - `Имя_папы` — имя папы коровы.
# - `Текущая_жирность,%` — содержание жиров в молоке (в процентах).
# - `Текущий_уровень_белок,%` — содержание белков в молоке (в процентах).
# - `Возраст` — возраст коровы, бинарный признак (менее 2 лет, более 2 лет).
#
# Данные в файлах ferma_main.csv и cow_buy.csv похожи, но у датасета cow_buy.csv несколько особенностей.
# Содержание белков и жиров в молоке указано на момент продажи — когда «ЭкоФерма» давала коровам свой корм.
# Параметры корма ЭКЕ (Энергетическая кормовая единица), Сырой протеин, г и СПО (Сахаро-протеиновое соотношение) отсутствуют. Технологи заказчика пересмотрели подход к кормлению: для новых коров планируется увеличить значения каждого из этих параметров на 5%.
# Кроме того, отсутствуют признаки Удой, кг и Вкус молока. Это целевые признаки, именно их предстоит предсказать!
#
# **План работы**
#
# 1. Провести предварительный обзор данных;
# 2. Провести предобработку данных;
# 3. Провести исследовательский анализ данных;
# 4. Провести корреляционный анализ;
# 5. Создать модель линейной регрессии;
# 6. Создать модель логистической регрессии для классификации;
# 7. Сформулировать общий вывод.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера  <a class="tocSkip"> </h2>
#
# 👍 Отлично по описанию. Цели, задачи и план ясны.
# </div>

# %% [markdown]
# ## 1 Загрузка данных

# %%
 # !pip install phik -q
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import phik
from scipy import stats as st
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import (r2_score,
                             mean_squared_error, 
                             mean_absolute_error, 
                             accuracy_score, 
                             precision_score,
                             recall_score, 
                             confusion_matrix, 
                             precision_recall_curve)
pd.set_option('display.max_columns', None)

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера  <a class="tocSkip"> </h2>
#
# 👍 Если добавить `-q` к загрузке, то логи выводиться не будут.
#
# `!pip install phik -q`
#
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Если загружаем несколько функций из одного пакета, то удобнее записать это через запятую.
#
# `from sklearn.metrics import r2_score, accuracy_score, precision_score, recall_score, confusion_matrix`
#
# А если через запятую будет больше трех-четырех позиций (а длина строки больше 90 символов), в таком случае здесь было бы идеально привести оформление в соответствие с <a href="https://pythonworld.ru/osnovy/pep-8-rukovodstvo-po-napisaniyu-koda-na-python.html">pep8</a> - не оставлять длинных строк.
#
# Такое оформление предпочтительнее:
#
# `from sklearn.metrics import (
#     accuracy_score,
#     confusion_matrix,
#     r2_score,
#     precision_score,
#     recall_score
# )`
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h5> Комментарий студента </h5>
#
# Поправил загрузку и вывод логов.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Cнова привет. Спасибо за заметное оформление твоих комментариев. По исправлениям отлично.
# </div>

# %%
ferma_main = pd.read_csv('/datasets/ferma_main.csv', sep=';', decimal=',')
ferma_dad = pd.read_csv('/datasets/ferma_dad.csv', sep=';', decimal=',')
cow_buy = pd.read_csv('/datasets/cow_buy.csv', sep=';', decimal=',')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Отлично, что указываешь разделитель с запятой для чисел.
# </div>

# %%
#Function for getting start information
def get_start_info(data):
    display(data.head())
    display(data.info())
    display(data.describe())

# %%
get_start_info(ferma_main)
# Out:
#    id  Удой, кг  ЭКЕ (Энергетическая кормовая единица)  Сырой протеин, г  \
# 0   1      5863                                   14.2              1743
# 1   2      5529                                   12.8              2138
# 2   3      5810                                   14.0              1854
# 3   4      5895                                   12.4              2012
# 4   5      5302                                   12.8              1675
#
#    СПО (Сахаро-протеиновое соотношение)           Порода Тип пастбища  \
# 0                                 0.890   Вис Бик Айдиал    Равнинное
# 1                                 0.890   Вис Бик Айдиал    Равнинные
# 2                                 0.885  РефлешнСоверинг    Холмистое
# 3                                 0.885  РефлешнСоверинг    Холмистое
# 4                                 0.885   Вис Бик Айдиал    Равнинные
#
#   порода папы_быка  Жирность,%  Белок,% Вкус молока      Возраст
# ...

# %%
get_start_info(ferma_dad)
# Out:
#    id  Имя Папы
# 0   1    Буйный
# 1   2  Соловчик
# 2   3     Барин
# 3   4    Буйный
# 4   5     Барин
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 629 entries, 0 to 628
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        629 non-null    int64
#  1   Имя Папы  629 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 10.0+ KB
# None
#               id
# count  629.00000
# mean   315.00000
# std    181.72094
# min      1.00000
# 25%    158.00000
# 50%    315.00000
# 75%    472.00000
# max    629.00000

# %%
get_start_info(cow_buy)
# Out:
#             Порода Тип пастбища порода папы_быка  Имя_папы  \
# 0   Вис Бик Айдиал    холмистое           Айдиал  Геркулес
# 1   Вис Бик Айдиал    равнинное          Соверин    Буйный
# 2  РефлешнСоверинг    равнинное          Соверин     Барин
# 3  РефлешнСоверинг    холмистое           Айдиал    Буйный
# 4  РефлешнСоверинг    равнинное           Айдиал    Буйный
#
#    Текущая_жирность,%  Текущий_уровень_белок,%      Возраст
# 0                3.58                    3.076  более_2_лет
# 1                3.54                    3.081  менее_2_лет
# 2                3.59                    3.074  более_2_лет
# 3                3.40                    3.061  более_2_лет
# 4                3.64                    3.074  более_2_лет
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
# ...

# %% [markdown]
# ### Вывод
#
# Исходя из предварительного обзора данных, можно сделать следующие выводы:
# - Датасет `ferma_main`:
#     - Всего в датасете 634 строки и 12 столбцов;
#     - Необходимо привести названия столбцов к единому стилю;
#     - Необходимо проверить данные на дубликаты;
#     - Необходимо проверить данные на вбросы (числа в удое выглядят подозрительными).
#
# - Датасет `ferma_dad`:
#     - Всего в датасете 629 строк и 2 столбца;
#     - Необходимо привести названия столбцов к единому стилю;
#     - Необходимо проверить данные на дубликаты.
# - Датасет `cow_buy`:
#     - Всего в датасете 20 строк и 7 столбцов;
#     - Необходимо привести названия столбцов к единому стилю.
#
# Данные являются пригодными для исследования.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Верно, часть проблем с данными замечена. Данные действительно достаточно качественные.
# </div>

# %% [markdown]
# ##  2 Предобработка данных

# %% [markdown]
# ### 2.1 Датасет `ferma_main`

# %% [markdown]
# #### 2.1.1 Названия столбцов
#
# В названиях столбцов оставим русский алфавит за исключением id, в отсальных случаях првиедем названия к змеиному регистру.

# %%
ferma_main.rename(columns={
    'Удой, кг': 'удой',
    'ЭКЕ (Энергетическая кормовая единица)': 'эке',
    'Сырой протеин, г':'сырой_протеин',
    'СПО (Сахаро-протеиновое соотношение)':'спо',
    'Порода':'порода',
    'Тип пастбища':'тип_пастбища',
    'порода папы_быка':'порода_папы',
    'Жирность,%':'жирность',
    'Белок,%':'белок',
    'Вкус молока':'вкус_молока',
    'Возраст':'возраст'}, inplace=True)
ferma_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 634 entries, 0 to 633
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             634 non-null    int64
#  1   удой           634 non-null    int64
#  2   эке            634 non-null    float64
#  3   сырой_протеин  634 non-null    int64
#  4   спо            634 non-null    float64
#  5   порода         634 non-null    object
#  6   тип_пастбища   634 non-null    object
#  7   порода_папы    634 non-null    object
#  8   жирность       634 non-null    float64
#  9   белок          634 non-null    float64
#  10  вкус_молока    634 non-null    object
#  11  возраст        634 non-null    object
# dtypes: float64(4), int64(3), object(5)
# memory usage: 59.6+ KB

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Отлично по переименованию колонок.
# </div>

# %% [markdown]
# #### 2.1.2 Дубликаты в данных

# %% [markdown]
# #### 2.1.2.1 Явные дубликаты

# %%
ferma_main.duplicated().sum()
# Out:
# 5

# %%
ferma_main.drop_duplicates(inplace=True)
ferma_main.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### 2.1.2.2 Неявные дубликаты
#
# Проверим на неявные дубликаты столбцы `порода`, `тип_пастбища`, `порода_папы`, `вкус_молока`, `возраст`. Данные признаки выбраны, потому что они представлены не числовыми значениями.

# %%
for col in ['порода', 'тип_пастбища', 'порода_папы', 'вкус_молока', 'возраст']:
    print(f'{col}: {ferma_main[col].unique()}')
# Out:
# порода: ['Вис Бик Айдиал' 'РефлешнСоверинг']
# тип_пастбища: ['Равнинное' 'Равнинные' 'Холмистое']
# порода_папы: ['Айдиал' 'Соверин' 'Айдиалл']
# вкус_молока: ['вкусно' 'не вкусно']
# возраст: ['более_2_лет' 'менее_2_лет']

# %% [markdown]
# Как мы видим, в столбце `тип_пастбища` есть неявные дубликаты представленные 'Равнинное' и 'Равнинные', заменим 'Равнинные' на 'Равнинное'. Помимо этого в столбце `порода_папы` есть дубликат 'Айдиалл', заменим его на 'Айдиал'.

# %%
ferma_main['тип_пастбища'].replace({'Равнинные': 'Равнинное'}, inplace=True)
ferma_main['порода_папы'].replace({'Айдиалл': 'Айдиал'}, inplace=True)
#Проверим замены на корректность
print(ferma_main['тип_пастбища'].unique())
print(ferma_main['порода_папы'].unique())
# Out:
# ['Равнинное' 'Холмистое']
# ['Айдиал' 'Соверин']

# %% [markdown]
# ### 2.1.3 Вбросы в данных
#
# При предварительном обзоре датасетов было выявлено, что в столбце `удой` максимальное значение равно 45616 в то время, как медианное значение равно 6130. Проверим распределение этого столбца.

# %%
plt.hist(ferma_main['удой'], bins=30, label=['удой'])
plt.title('Среднее количество литров молока в год')
plt.legend(loc='upper right')
plt.xlabel('Количество литров в год, л')
plt.ylabel('Количество коров')
plt.grid()
plt.show()

# %% [markdown]
# Выведем выбивающиеся занчения больше 10000 и меньше 5000 литров в год.

# %%
ferma_main.query('удой > 10_000 or удой < 5_000')
# Out:
#     id   удой   эке  сырой_протеин   спо          порода тип_пастбища  \
# 16  17  45616  11.5           1675  0.93  Вис Бик Айдиал    Холмистое
#
#    порода_папы  жирность  белок вкус_молока      возраст
# 16      Айдиал      3.22  3.076      вкусно  более_2_лет

# %% [markdown]
# Вброс в данном датасете только один, его можно объяснить, вероятно, технической ошибкой. Удалим эту строку, так как на выборку повлияет назначительно.

# %%
ferma_main = ferma_main.query('удой != 45616').reset_index(drop=True)
#Check our changes
plt.hist(ferma_main['удой'], bins=30, label=['удой'])
plt.title('Среднее количество литров молока в год')
plt.legend(loc='upper right')
plt.xlabel('Количество литров в год, л')
plt.ylabel('Количество коров')
plt.grid()
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Согласен.
# </div>

# %% [markdown]
# ### 2.2 Датасет `ferma_dad`

# %% [markdown]
# #### 2.2.1 Названия столбцов
#
# Изменим названия столбцов на змеиный регистр, также удалим строку с `id`=17, так как в прошлом пункте мы удалили эту корову из выборки.

# %%
ferma_dad.rename(columns={'Имя Папы': 'имя_папы'}, inplace=True)
ferma_dad = ferma_dad.query('id != 17').reset_index(drop=True)
ferma_dad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 628 entries, 0 to 627
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        628 non-null    int64
#  1   имя_папы  628 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 9.9+ KB

# %% [markdown]
# #### 2.2.2 Дубликаты в данных

# %% [markdown]
# ##### 2.2.2.1 Явные дубликаты

# %%
ferma_dad.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### 2.2.2.2 Неявные дубликаты

# %%
ferma_dad['имя_папы'].unique()
# Out:
# array(['Буйный', 'Соловчик', 'Барин', 'Геркулес'], dtype=object)

# %% [markdown]
# ### 2.3 Датасет `cow_buy`

# %% [markdown]
# #### 2.3.1 Названия столбцов

# %%
cow_buy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Порода                   20 non-null     object
#  1   Тип пастбища             20 non-null     object
#  2   порода папы_быка         20 non-null     object
#  3   Имя_папы                 20 non-null     object
#  4   Текущая_жирность,%       20 non-null     float64
#  5   Текущий_уровень_белок,%  20 non-null     float64
#  6   Возраст                  20 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 1.2+ KB

# %%
cow_buy.rename(columns={
    'Порода':'порода',
    'Тип пастбища':'тип_пастбища',
    'порода папы_быка':'порода_папы',
    'Имя_папы': 'имя_папы',
    'Текущая_жирность,%':'текущая_жирность',
    'Текущий_уровень_белок,%':'текущий_белок',
    'Возраст':'возраст'}, inplace=True)

cow_buy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   порода            20 non-null     object
#  1   тип_пастбища      20 non-null     object
#  2   порода_папы       20 non-null     object
#  3   имя_папы          20 non-null     object
#  4   текущая_жирность  20 non-null     float64
#  5   текущий_белок     20 non-null     float64
#  6   возраст           20 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 1.2+ KB

# %%
#Заменим на значение идентичное в ferma_main, потому что при обучении вылезла ошибка о несовпадении
cow_buy['тип_пастбища'] = cow_buy['тип_пастбища'].str.capitalize()

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Здесь также можно проверить на неявные дубли.

# %% [markdown]
# <div class="alert alert-info">
# <h5> Комментарий студента </h5>
#
# Думал об этом, но не совсем понял, где они могут быть. Просмотрел весь датасет, есть, конечно, совпадения строк, но id при этом разный. Предположил, что ну может же быть две коровы одной породы от одного быка с одинкаовой жирностью, тем более, что разброс жирности и белк не так велик, совпадение вполне могло быть.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Ок, здесь просто можно обозначить, что мы не забыли их исследовать.
#
# Явные дубли в этой таблице действительно удалять не нужно.
# </div>

# %% [markdown]
# ### 2.3 Объединение датасетов `ferma_main` и `ferma_dad`
#
# Поскольку при удалении выброса нам пришлось редактировать сразу два датасета, для длаьнейшей работы объединим датасеты `ferma_main` и `ferma_dad`.

# %%
ferma_full = pd.merge(ferma_main, ferma_dad, on='id')
ferma_full.head()
# Out:
#    id  удой   эке  сырой_протеин    спо           порода тип_пастбища  \
# 0   1  5863  14.2           1743  0.890   Вис Бик Айдиал    Равнинное
# 1   2  5529  12.8           2138  0.890   Вис Бик Айдиал    Равнинное
# 2   3  5810  14.0           1854  0.885  РефлешнСоверинг    Холмистое
# 3   4  5895  12.4           2012  0.885  РефлешнСоверинг    Холмистое
# 4   5  5302  12.8           1675  0.885   Вис Бик Айдиал    Равнинное
#
#   порода_папы  жирность  белок вкус_молока      возраст  имя_папы
# 0      Айдиал      3.58  3.076      вкусно  более_2_лет    Буйный
# 1     Соверин      3.54  3.079      вкусно  менее_2_лет  Соловчик
# 2     Соверин      3.59  3.074   не вкусно  более_2_лет     Барин
# 3      Айдиал      3.40  3.075   не вкусно  более_2_лет    Буйный
# 4     Соверин      3.73  3.073      вкусно  менее_2_лет     Барин

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Ок.
# </div>

# %% [markdown]
# ### 2.4 Вывод
#
# В ходе предобработки данных проделаны следующие шаги:
#
# - Датасет `ferma_main`:
#     - Названия столбцов приведены к общему виду;
#     - Удалены явные дубликаты в данных (вероятно, из-за технической ошибки);
#     - Обработаны неявные дубликаты (вероятно, человеческий фактор);
#     - Удален вброс в данных признака `удой`.
# - Датасет `ferma_dad`:
#     - Названия столбцов приведены к общему виду;
#     - Данные проверены на дубликаты, выявлено не было.
# - Датасет `cow_buy`:
#     - Названия столбцов приведены к общему виду.
# - Датасет `ferma_full`:
#     - Путем объединения `ferma_main` и `ferma_dad` был получен датасет `ferma_full`.

# %% [markdown]
# ## 3 Исследовательский анализ данных
#
# Необходимо провести исследовательский анализ с признаками датасета `ferma_full`, их можно разделить на количественные (`удой`, `эке`, `сырой_протеин`, `спо`, `жирность`, `белок`) и категориальные (`порода`, `тип_пастбища`, `порода_папы`, `вкус_молока`, `возраст`, `имя_папы`).

# %% [markdown]
# ### 3.1 Признак `удой`

# %%
plt.hist(ferma_full['удой'], bins=30, edgecolor='black', label=['удой'])
plt.title('Распределение среднего количество литров молока в год')
plt.xlabel('Количество литров в год, л')
plt.ylabel('Количество коров')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.boxplot(ferma_full['удой'])
plt.title(f'Средний удой с выбросами')
plt.ylabel('Количество литров, л');

# %% [markdown]
# ### 3.2 Признак `эке`

# %%
plt.figure(figsize=(10,5))
plt.hist(ferma_full['эке'], bins=50, edgecolor='black')
plt.title('Распределение ЭКЕ (энергетической кормовой единицы)')
plt.xlabel('Значение ЭКЕ')
plt.ylabel('Количество коров')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.boxplot(ferma_full['эке'])
plt.title(f'Энергетическая кормовая единица с выбросами')
plt.ylabel('Значение ЭКЕ');

# %% [markdown]
# ### 3.3 Признак `сырой_протеин`

# %%
plt.figure(figsize=(10,5))
plt.hist(ferma_full['сырой_протеин'], bins=50, edgecolor='black')
plt.title('Распределение содержания сырого протеина в корме')
plt.xlabel('Содержание сырого протеина, г')
plt.ylabel('Количество коров')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.boxplot(ferma_full['сырой_протеин'])
plt.title(f'Содержание сырого протеина с выбросами')
plt.ylabel('Содеражание сырого протеина, г');

# %% [markdown]
# ### 3.4 Признак `спо`

# %%
plt.figure(figsize=(10,5))
plt.hist(ferma_full['спо'], bins=30, edgecolor='black')
plt.title('Распределение СПО (Сахаро-протеинового соотношения) в корме')
plt.xlabel('Значение СПО')
plt.ylabel('Количество коров')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.boxplot(ferma_full['спо'])
plt.title(f'Сахаро-протеиновое соотношение с выбросами')
plt.ylabel('Значение СПО');

# %% [markdown]
# ### 3.5 Признак `жирность`

# %%
plt.figure(figsize=(10,5))
plt.hist(ferma_full['жирность'], bins=20, edgecolor='black')
plt.title('Распределение содержания жира в молоке')
plt.xlabel('Значение жирности, %')
plt.ylabel('Количество коров')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.boxplot(ferma_full['жирность'])
plt.title(f'Значение жирности с выбросами')
plt.ylabel('Значение жирности, %');

# %%
print(f'Доля выбросов признака жирности составляет {round(len(ferma_full.query("жирность < 3.4")) / len(ferma_full) * 100, 2)}%')
# Out:
# Доля выбросов признака жирности составляет 13.69%

# %% [markdown]
# **Вывод**
#
# Наблюдаются выбросы в значениях жирности меньше 3.4, их доля от общего числа составляет почти 14 процентов. Выбросы так же имеют реалистичные значения, такая жирность вполне может быть в зависимости от корма. Поскольку количество выбросов велико для выборки и значения реалистичны, данные оставляем.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Хорошая аргументация.
# </div>

# %% [markdown]
# ### 3.6 Признак `белок`

# %%
plt.figure(figsize=(10,5))
plt.hist(ferma_full['белок'], bins=30, edgecolor='black')
plt.title('Распределение содержания белка в молоке')
plt.xlabel('Значение белка, %')
plt.ylabel('Количество коров')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.boxplot(ferma_full['белок'])
plt.title(f'Значение белка с выбросами')
plt.ylabel('Значение белка, %');

# %% [markdown]
# **Вывод**
#
# Такие выбросы так же можно объяснить кормом и условиями содержания коровы, но поскольку количество выбросов невелико в соотнешении со всей выборкой, можно избавиться от этих выбросов.

# %%
#Найдем границы разброса с полуторным межквартильным интервалом
q1, q3 = np.percentile(ferma_full['белок'], [25, 75])
iqr = q3 - q1
minimum = q1 - 1.5 * iqr
maximum = q3 + 1.5 * iqr

print(f"Доля выбросов составляет {round((1 - len(ferma_full.query('@minimum < белок < @maximum')) / len(ferma_full)) * 100, 3)}%")
# Out:
# Доля выбросов составляет 0.796%

# %%
#Избавимся от выбросов и проверим boxplot снова
ferma_full = ferma_full.query('@minimum < белок < @maximum').reset_index(drop=True)

plt.figure(figsize=(10,5))
plt.boxplot(ferma_full['белок'])
plt.title(f'Значение белка с выбросами')
plt.ylabel('Значение белка, %');

# %% [markdown]
# ### 3.7 Категориальные признаки
#
# У категориальных переменных мы можем оценить распределение и представить их соотношение. Категориальные признаки следующие: `порода`, `тип_пастбища`, `порода_папы`, `вкус_молока`, `возраст`, `имя_папы`.

# %%
features = ['порода', 'тип_пастбища', 'порода_папы', 'вкус_молока', 'возраст', 'имя_папы']

for feature in features:
    display(ferma_full.pivot_table(index=feature,  values='id', aggfunc='count').rename(columns={'id': 'количество'}))
    plt.figure(figsize=(7,7))
    plt.pie(ferma_full[feature].value_counts(), autopct='%1.2f%%', labels=dict(ferma_full[feature].value_counts()).keys())
    plt.title(f'Распределение признака `{feature}`')
    plt.legend(loc='upper right');
# Out:
#                  количество
# порода
# Вис Бик Айдиал          368
# РефлешнСоверинг         255
#               количество
# тип_пастбища
# Равнинное            275
# Холмистое            348
#              количество
# порода_папы
# Айдиал              314
# Соверин             309
#              количество
# вкус_молока
# вкусно              366
# не вкусно           257
#              количество
# возраст
# более_2_лет         514
# менее_2_лет         109
#           количество
# имя_папы
# Барин            240
# Буйный           212
# Геркулес          64
# Соловчик         107

# %% [markdown]
# ### 3.8 Вывод
#
# По исследовательскому анализу можно сделать следующие выводы:
# - Количественные признаки:
#     - Признак `удой` распределен нормально, имеет среднее значение около 6100 кг;
#     - Признак `эке`распределен нормально, выбросов не имеет, среднее значение около 14.5;
#     - Признак `сырой_протеин` не распределен нормально, вероятно, это связано со спецификой переменной. Выбросов не имеет, среднее значение около 1900 г.
#     - Признак `спо` не имеет нормального распределения, вероятно, из-за специфики значения. Выбросов не имеет, среднее значение 0.93.
#     - Признак `жирность`. Наблюдаются выбросы в значениях жирности меньше 3.4, их доля от общего числа составляет почти 14 процентов. Выбросы так же имеют реалистичные значения, такая жирность вполне может быть в зависимости от корма. Поскольку количество выбросов велико для выборки и значения реалистичны, данные оставляем.
#     - Признак `белок` имеет нормальное распределение, имеет выбросы, которые так же можно объяснить кормом и условиями содержания коровы, но поскольку количество выбросов невелико в соотнешении со всей выборкой, можно избавиться от этих выбросов.
# - Категориальные признаки:
#     - Признаки `порода`, `тип_пастбища`, `порода_папы` и `вкус_молока` имеют близкое отношение 1:1;
#     - Признак `возраст` распределяется на более_2_лет (82.5%) и менее_2_лет (17.5%);
#     - Признак `имя_папы` показывает самых многодетных отцов: Барина (38.52%) и Буйного (34.03%).
# - Общий вывод:
#     - Данные пригодны для дальнейшего исследования, критических изменений не внесено.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Супер, не забыли прокомментировать и нормальность распределения. СПО, Жирность распределены не нормально.
# </div>

# %% [markdown]
# ## 4 Корреляционный анализ
#
# Перед созданием моделей машинного обучения необходимо провести корреляционный анализ, чтобы выяснить с чем коррелирует целевой признак и есть ли линейно-зависимые переменные.

# %%
#Матрица корреляции с числовыми признаками
#plt.figure(figsize=(8,7))
#sns.heatmap(ferma_full.drop('id', axis=1).corr(), annot=True, cmap='magma');

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Если выше мы заметили, что не все признаки распределены нормально, то здесь нужно использовать корреляцию Спирмана или Phik или иные подходы, которые устойчивы к выбросам и ненормальному распределению. Корреляция Пирсона, которая здесь используется по умолчанию, нам не подходит.
#
#
# Я бы этот способ убрал, хотя и видим, что по коэффициентам искажение небольшое.

# %% [markdown]
# <div class="alert alert-info">
# <h5> Комментарий студента </h5>
#
# Понял, принял. Но пока оставлю в комментарии, чтобы было видно над чем работал.
# </div>

# %%
#Матрица корреляции со всеми признаками
plt.figure(figsize=(8, 7))
sns.heatmap(ferma_full.drop('id', axis=1).phik_matrix(), annot=True, cmap='magma');
# Out:
# interval columns not set, guessing: ['удой', 'эке', 'сырой_протеин', 'спо', 'жирность', 'белок']

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Согласен.
#
# Единственное замечание, при использовании **phik** желательно настроить параметр **interval_cols**, передав ему список с названиями количественных признаков. Phik разделяет признаки на категориальные и количественные автоматически, но часто совершает ошибки, поэтому правильно будет указать все в явном виде.
#
# `.phik_matrix(interval_cols=['признак_1','признак_2','признак_3','признак_4','признак_5'])`
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h5> Комментарий студента </h5>
#
# 👍 Круто.
# </div>

# %%
features = ['эке', 'сырой_протеин', 'спо', 'жирность', 'белок']

for feature in features:
    plt.figure(figsize=(10,5))
    sns.scatterplot(data=ferma_full, x=feature, y='удой', hue='порода')
    plt.title(f"Корреляция между целевым показателем `удой` и `{feature}`")
    plt.xlabel(f'Значение {feature}')
    plt.ylabel('Удой, л')
    plt.grid()
    plt.show()

# %% [markdown]
# **Вывод**
#
# Корреляционный анализ был направлен на изучение корреляции целевого признака с входными, поэтому выводы будут для каждой входной характеристики, влияющей на целевой признак `удой`.
# В результате корреляционного анализа были сделаны следующие выводы:
# - `эке` имеет высокую прямую корреляцию, равную 0.72. Причем вне зависимости от породы график рассеения имеет общий тренд. Наблюдается квадратичная зависимость с удоем.
# - `сырой_протеин`имеет умеренную прямую корреляцию, равную 0.47. Причем вне зависимости от породы график рассеения имеет общий тренд.
# - `спо` имеет заметную прямую корреляцию, равную 0.66. Распредление точек на графике рассеяния примерно одинаковое для обеих пород. Наблюдается нелинейная связь в виде кластеризации.
# - `жирность` имеет высокую прямую корреляцию, равную 0.71. Разброс на графиках рассеяния достаточно большой, но наблюдаются наиболее плотные скопления точек при значениях 3.6 и 3.7.
# - `белок` имеет слабую прямую корреляцию, равную 0.21. Значение белка в молоке больше у породы Вис Бик Айдиал, но явно выраженной зависимости количества удоя от значения белка не наблюдается.
# - Между входными и целевым признаками наблюдается явная линейная связь.
# - Значимых нелинейных зависимостей между входными и целевым признаками не обнаружено, разве что `спо`, но незначительно.
# - Мультиколлинеарность обнаружена между признаками `порода_папы` и `имя_папы`. Удалим столбец `имя папы`, напомню, что объединяли мы его для более комфортной работы при предобработке данных.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# По СПО видим кластеризацию − связь нелинейная.
#
# По ЭКЕ и удою у нас что-то среднее между линейной и квадратичной зависимостью. Если присмотреться, можно увидеть кривую, похожую на ветвь паработы - графика квадратичной функции. В проекте нам предлагается устранить здесь квадратичную зависимость (взять квадрат признака), чтобы модель могла корректно учитывать признак.
#
# ***
#
# Линейная связь на скаттерплоте выглядит как вытянутое в линию облако точек. Чем больше оно вытянуто, тем сильнее связь. Если связь совсем слабая, облако почти круглое.
#
# * Если облако кривое − квадратичная зависимость.
# * если облаков несколько − тенденция к кластеризации.
#
# Оба варианта не относятся к линейной зависимости. Важно еще раз внимательно посмотреть на скаттерплоты и перечислить, где у нас не наблюдается линейной зависимости. Дальше в проекте при построении второй итерации линейной модели нам предлагается исключить нелинейность. Как увидим, это повышает качество модели.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h5> Комментарий студента </h5>
#
# Очень хорошее объяснение с облаками, стало понятнее. Поправил вывод.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Отлично! Все верно.
# </div>

# %%
ferma_ml = ferma_full.drop('имя_папы', axis=1)
ferma_ml.head()
# Out:
#    id  удой   эке  сырой_протеин    спо           порода тип_пастбища  \
# 0   1  5863  14.2           1743  0.890   Вис Бик Айдиал    Равнинное
# 1   2  5529  12.8           2138  0.890   Вис Бик Айдиал    Равнинное
# 2   3  5810  14.0           1854  0.885  РефлешнСоверинг    Холмистое
# 3   4  5895  12.4           2012  0.885  РефлешнСоверинг    Холмистое
# 4   5  5302  12.8           1675  0.885   Вис Бик Айдиал    Равнинное
#
#   порода_папы  жирность  белок вкус_молока      возраст
# 0      Айдиал      3.58  3.076      вкусно  более_2_лет
# 1     Соверин      3.54  3.079      вкусно  менее_2_лет
# 2     Соверин      3.59  3.074   не вкусно  более_2_лет
# 3      Айдиал      3.40  3.075   не вкусно  более_2_лет
# 4     Соверин      3.73  3.073      вкусно  менее_2_лет

# %%
#Матрица корреляции со всеми признаками
plt.figure(figsize=(8, 7))
sns.heatmap(ferma_ml.drop('id', axis=1).phik_matrix(), annot=True, cmap='magma');
# Out:
# interval columns not set, guessing: ['удой', 'эке', 'сырой_протеин', 'спо', 'жирность', 'белок']

# %% [markdown]
# Теперь мультиколлинеарности не наблюдается.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Хм. Пока не ясно, зачем тогда добавляли.
#
# Здесь, раз уж выше объединили таблицы, я бы заметил такую высокую корреляцию и прокомментировал ее. Ниже же я бы в разных моделях, согласно заданию, использовал разные наборы признаков. Где-то не использовал имя, а где-то − породу.

# %% [markdown]
# <div class="alert alert-info">
# <h5> Комментарий студента </h5>
#
# Объединял датасеты, чтобы не удалять дважды одну и ту же информацию в обоих датасетах. То есть если мы из `ferma_main` удаляем корову, то соответственно должны и из датасета `ferma_dad` удалить ее по `id`.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Ок. Необязательно, так как при объединении inner у нас в результирующую таблицу попадут только строки с имеющимися в двух датасетах id.
# </div>

# %% [markdown]
# ## 5 Обучение модели линейной регрессии
#
# Для подготовки данных к обучению для модели линейной регрессии необходимо избавиться от следующих столбцов:
# - `id`, никакого отношения к целевой характеристике он не имеет;
# - Характеристики молока, кроме удоя (так как характеристики молока зависят от коровы и условий, в которых она находится)
#     - `жирность` является характеристикой молока, а не коровы, которую необходимо выбирать;
#     - `белок`, является характеристикой молока и показал низкую корреляцию с целевым признаком;
#     - `вкус_молока`, является характеристикой молока, а не коровы.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍  Точно
# </div>

# %% [markdown]
# ### 5.1 Модель №1

# %%
# Создадим отдельный датасет для модели линейной регрессии
ferma_lr1 = ferma_ml.drop(['id', 'жирность', 'белок', 'вкус_молока'], axis=1)
ferma_lr1.head()
# Out:
#    удой   эке  сырой_протеин    спо           порода тип_пастбища порода_папы  \
# 0  5863  14.2           1743  0.890   Вис Бик Айдиал    Равнинное      Айдиал
# 1  5529  12.8           2138  0.890   Вис Бик Айдиал    Равнинное     Соверин
# 2  5810  14.0           1854  0.885  РефлешнСоверинг    Холмистое     Соверин
# 3  5895  12.4           2012  0.885  РефлешнСоверинг    Холмистое      Айдиал
# 4  5302  12.8           1675  0.885   Вис Бик Айдиал    Равнинное     Соверин
#
#        возраст
# 0  более_2_лет
# 1  менее_2_лет
# 2  более_2_лет
# 3  более_2_лет
# 4  менее_2_лет

# %%
#Cоздание константы RANDOM_STATE
RANDOM_STATE = 42
#Подготовка выборок
X = ferma_lr1.drop('удой', axis=1)
y = ferma_lr1['удой']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=RANDOM_STATE)

num_col_names = ['эке', 'сырой_протеин', 'спо']
cat_col_names = ['порода', 'тип_пастбища', 'порода_папы', 'возраст']

# %%
#Кодирование категориальных признаков
encoder = OneHotEncoder(drop='first', sparse=False)
X_train_ohe = encoder.fit_transform(X_train[cat_col_names])
X_test_ohe = encoder.transform(X_test[cat_col_names])

encoder_col_names = encoder.get_feature_names()

#Масштабирование количественных признаков
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train[num_col_names])
X_test_scaled = scaler.transform(X_test[num_col_names])

#Формирование выборок
X_train_ohe = pd.DataFrame(X_train_ohe, columns=encoder_col_names)
X_test_ohe = pd.DataFrame(X_test_ohe, columns=encoder_col_names)

X_train_scaled = pd.DataFrame(X_train_scaled, columns=num_col_names)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=num_col_names)

X_train = pd.concat([X_train_ohe, X_train_scaled], axis=1)
X_test = pd.concat([X_test_ohe, X_test_scaled], axis=1)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Всё верно
#
# </div>

# %%
model_lr1 = LinearRegression()
model_lr1.fit(X_train, y_train)
predictions_1 = model_lr1.predict(X_test)

mse_1 = mean_squared_error(y_test, predictions_1)
rmse_1 = mean_squared_error(y_test, predictions_1, squared=False)
mae_1 = mean_absolute_error(y_test, predictions_1)
r2_1 = r2_score(y_test, predictions_1)

print(f'Среднеквадратичная ошибка равна {mse_1}')
print(f'Квадратный корень из среднеквадратичной ошибки равен {rmse_1}')
print(f'Средняя абсолютная ошибка равна {mae_1}')
print(f'Коэффициент детерминации равен {r2_1}')
# Out:
# Среднеквадратичная ошибка равна 47499.999455259895
# Квадратный корень из среднеквадратичной ошибки равен 217.94494592731417
# Средняя абсолютная ошибка равна 173.80122314737423
# Коэффициент детерминации равен 0.7832029531509055

# %%
residuals_1 = y_test - predictions_1
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
axes[0].hist(residuals_1, bins=50, edgecolor='black')
axes[0].set_title('Гистограмма распределения остатков')
axes[0].set_xlabel('Остатки')

axes[1].scatter(predictions_1, residuals_1)
axes[1].set_xlabel('Предсказания модели')
axes[1].set_ylabel('Остатки')
axes[1].set_title('Анализ дисперсии')
plt.show()

# %% [markdown]
# **Вывод**
#
# В ходе работы с моделью линейной регрессии №1 можно сделать следующие выводы:
# - Среднеквадратичная ошибка равна 47500;
# - Квадратный корень из среднеквадратичной ошибки равен 217.94;
# - Средняя абсолютная ошибка равна 173.8;
# - Коэффициент детерминации равен 0.78;
# - Гистограмма остатков распределена нормально около нулевого значения;
# - Дисперсия предсказаний постоянна на всех участках, только в значениях около 6000 наблюдается небольшое отсутсвтие значений;
# - Для улучшения моделирования можно добавить данных по коровам с удоем в районе 6000 л и менее 5500 л.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Ок, действительно, можно обогатить модель данными.
#
# По заданию дальше будем изменять признаки, связанные с таргетом нелинейно. Тогда логично здесь написать, что для улучшения модели можно поработать с нелинейностью.
#
# </div>

# %% [markdown]
# ### 5.2 Модель №2

# %%
# Создадим отдельный датасет для модели линейной регрессии, избавимся от ненужных признаков
ferma_lr2 = ferma_ml.drop(['id', 'жирность', 'белок', 'вкус_молока'], axis=1)
#Преобразование СПО, на графике рассеяния виден провал на значениях от 0.91 до 0.92, возьем среднее между ними - 0.915.
ferma_lr2['спо_кат'] = ferma_lr2['спо'].apply(lambda x: 1 if x >= 0.915 else 0)
ferma_lr2['эке_квад'] = ferma_lr2['эке'] ** 2
ferma_lr2.drop(['спо', 'эке'], axis=1, inplace=True)
ferma_lr2.head(10)
# Out:
#    удой  сырой_протеин           порода тип_пастбища порода_папы      возраст  \
# 0  5863           1743   Вис Бик Айдиал    Равнинное      Айдиал  более_2_лет
# 1  5529           2138   Вис Бик Айдиал    Равнинное     Соверин  менее_2_лет
# 2  5810           1854  РефлешнСоверинг    Холмистое     Соверин  более_2_лет
# 3  5895           2012  РефлешнСоверинг    Холмистое      Айдиал  более_2_лет
# 4  5302           1675   Вис Бик Айдиал    Равнинное     Соверин  менее_2_лет
# 5  5254           1806  РефлешнСоверинг    Холмистое     Соверин  менее_2_лет
# 6  5910           1792   Вис Бик Айдиал    Равнинное     Соверин  более_2_лет
# 7  6179           1806   Вис Бик Айдиал    Равнинное      Айдиал  более_2_лет
# 8  6783           1918  РефлешнСоверинг    Холмистое      Айдиал  более_2_лет
# 9  5339           1791   Вис Бик Айдиал    Холмистое     Соверин  менее_2_лет
#
#    спо_кат  эке_квад
# 0        0    201.64
# 1        0    163.84
# 2        0    196.00
# 3        0    153.76
# ...

# %%
#Cоздание константы RANDOM_STATE
RANDOM_STATE = 42
#Подготовка выборок
X = ferma_lr1.drop('удой', axis=1)
y = ferma_lr1['удой']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=RANDOM_STATE)

num_col_names = ['эке_квад', 'сырой_протеин', 'спо_кат']
cat_col_names = ['порода', 'тип_пастбища', 'порода_папы', 'возраст']

# %%
#Cоздание константы RANDOM_STATE
RANDOM_STATE = 42
#Подготовка выборок
X = ferma_lr2.drop('удой', axis=1)
y = ferma_lr2['удой']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=RANDOM_STATE)

num_col_names = ['сырой_протеин', 'эке_квад']
cat_col_names = ['порода', 'тип_пастбища', 'порода_папы', 'возраст', 'спо_кат']

# %%
#Кодирование категориальных признаков
encoder = OneHotEncoder(drop='first', sparse=False)
X_train_ohe = encoder.fit_transform(X_train[cat_col_names])
X_test_ohe = encoder.transform(X_test[cat_col_names])

encoder_col_names = encoder.get_feature_names()

#Масштабирование количественных признаков
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train[num_col_names])
X_test_scaled = scaler.transform(X_test[num_col_names])

#Формирование выборок
X_train_ohe = pd.DataFrame(X_train_ohe, columns=encoder_col_names)
X_test_ohe = pd.DataFrame(X_test_ohe, columns=encoder_col_names)

X_train_scaled = pd.DataFrame(X_train_scaled, columns=num_col_names)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=num_col_names)

X_train = pd.concat([X_train_ohe, X_train_scaled], axis=1)
X_test = pd.concat([X_test_ohe, X_test_scaled], axis=1)

# %%
model_lr2 = LinearRegression()
model_lr2.fit(X_train, y_train)
predictions_2 = model_lr2.predict(X_test)

mse_2 = mean_squared_error(y_test, predictions_2)
rmse_2 = mean_squared_error(y_test, predictions_2, squared=False)
mae_2 = mean_absolute_error(y_test, predictions_2)
r2_2 = r2_score(y_test, predictions_2)

print(f'Среднеквадратичная ошибка равна {mse_2}')
print(f'Квадратный корень из среднеквадратичной ошибки равен {rmse_2}')
print(f'Средняя абсолютная ошибка равна {mae_2}')
print(f'Коэффициент детерминации равен {r2_2}')
# Out:
# Среднеквадратичная ошибка равна 36207.49001635706
# Квадратный корень из среднеквадратичной ошибки равен 190.28265821234749
# Средняя абсолютная ошибка равна 149.71979977040343
# Коэффициент детерминации равен 0.8347436421181884

# %%
residuals_2 = y_test - predictions_2
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
axes[0].hist(residuals_2, bins=50, edgecolor='black')
axes[0].set_title('Гистограмма распределения остатков')
axes[0].set_xlabel('Остатки')

axes[1].scatter(predictions_2, residuals_2)
axes[1].set_xlabel('Предсказания модели')
axes[1].set_ylabel('Остатки')
axes[1].set_title('Анализ дисперсии')
plt.show()

# %% [markdown]
# **Вывод**
#
# В ходе работы с моделью линейной регрессии №2 можно сделать следующие выводы:
# - Среднеквадратичная ошибка равна 36207;
# - Квадратный корень из среднеквадратичной ошибки равен 190.28;
# - Средняя абсолютная ошибка равна 149.72;
# - Коэффициент детерминации равен 0.83;
# - Гистограмма остатков распределена нормально около нулевого значения;
# - Дисперсия предсказаний постоянна на всех участках, только в значениях около 6000-6250 наблюдается небольшое отсутсвтие значений;
# - Для улучшения моделирования можно избавиться от нелинейности в признаках `спо` и `эке`, и также добавить признак `имя_папы`.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Ок.
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# `Для улучшения моделирования можно добавить данных по коровам с удоем в районе 6000 л.` - все-таки смущает эта формулирвка. Здесь предполагается, что мы предлагаем идеи, которые можем реализовать. После первой итерации предлагаем учитывать нелинейность. После второй − добавить признак имени папы_быка.

# %% [markdown]
# <div class="alert alert-info">
# <h5> Комментарий студента </h5>
#
# Понял. Поправил.
# </div>

# %% [markdown]
# ### 5.3 Модель №3

# %%
# Создадим отдельный датасет для модели линейной регрессии, избавимся от ненужных признаков
ferma_lr3 = ferma_full.drop(['id', 'жирность', 'белок', 'вкус_молока'], axis=1)
#Преобразование СПО, на графике рассеяния виден провал на значениях от 0.91 до 0.92, возьем среднее между ними - 0.915.
ferma_lr3['спо_кат'] = ferma_lr3['спо'].apply(lambda x: 1 if x >= 0.915 else 0)
ferma_lr3['эке_квад'] = ferma_lr3['эке'] ** 2
ferma_lr3.drop(['спо', 'эке', 'порода_папы'], axis=1, inplace=True)
ferma_lr3.head(10)
# Out:
#    удой  сырой_протеин           порода тип_пастбища      возраст  имя_папы  \
# 0  5863           1743   Вис Бик Айдиал    Равнинное  более_2_лет    Буйный
# 1  5529           2138   Вис Бик Айдиал    Равнинное  менее_2_лет  Соловчик
# 2  5810           1854  РефлешнСоверинг    Холмистое  более_2_лет     Барин
# 3  5895           2012  РефлешнСоверинг    Холмистое  более_2_лет    Буйный
# 4  5302           1675   Вис Бик Айдиал    Равнинное  менее_2_лет     Барин
# 5  5254           1806  РефлешнСоверинг    Холмистое  менее_2_лет     Барин
# 6  5910           1792   Вис Бик Айдиал    Равнинное  более_2_лет  Соловчик
# 7  6179           1806   Вис Бик Айдиал    Равнинное  более_2_лет  Геркулес
# 8  6783           1918  РефлешнСоверинг    Холмистое  более_2_лет    Буйный
# 9  5339           1791   Вис Бик Айдиал    Холмистое  менее_2_лет     Барин
#
#    спо_кат  эке_квад
# 0        0    201.64
# 1        0    163.84
# 2        0    196.00
# 3        0    153.76
# ...

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Видим высокую корреляцию. Раз взяли имя_папы_быка, то можно не брать породу_папы_быка

# %% [markdown]
# <div class="alert alert-info">
# <h5> Комментарий студента </h5>
#
# Поправил. Результат не сильно изменился, модель стала чуток точнее.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Да, конкретно здесь мультиколлинеарность не проявляется, но раз уж видим два почти идентичных признака, имеет смысл убрать высокую корреляцию.
# </div>

# %%
#Cоздание константы RANDOM_STATE
RANDOM_STATE = 42
#Подготовка выборок
X = ferma_lr3.drop('удой', axis=1)
y = ferma_lr3['удой']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=RANDOM_STATE)

num_col_names = ['сырой_протеин', 'эке_квад']
cat_col_names = ['порода', 'тип_пастбища', 'возраст', 'спо_кат', 'имя_папы']

# %%
#Кодирование категориальных признаков
encoder = OneHotEncoder(drop='first', sparse=False)
X_train_ohe = encoder.fit_transform(X_train[cat_col_names])
X_test_ohe = encoder.transform(X_test[cat_col_names])

encoder_col_names = encoder.get_feature_names()

#Масштабирование количественных признаков
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train[num_col_names])
X_test_scaled = scaler.transform(X_test[num_col_names])

#Формирование выборок
X_train_ohe = pd.DataFrame(X_train_ohe, columns=encoder_col_names)
X_test_ohe = pd.DataFrame(X_test_ohe, columns=encoder_col_names)

X_train_scaled = pd.DataFrame(X_train_scaled, columns=num_col_names)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=num_col_names)

X_train = pd.concat([X_train_ohe, X_train_scaled], axis=1)
X_test = pd.concat([X_test_ohe, X_test_scaled], axis=1)

# %%
model_lr3 = LinearRegression()
model_lr3.fit(X_train, y_train)
predictions_3 = model_lr3.predict(X_test)

mse_3 = mean_squared_error(y_test, predictions_3)
rmse_3 = mean_squared_error(y_test, predictions_3, squared=False)
mae_3 = mean_absolute_error(y_test, predictions_3)
r2_3 = r2_score(y_test, predictions_3)

print(f'Среднеквадратичная ошибка равна {mse_3}')
print(f'Квадратный корень из среднеквадратичной ошибки равен {rmse_3}')
print(f'Средняя абсолютная ошибка равна {mae_3}')
print(f'Коэффициент детерминации равен {r2_3}')
# Out:
# Среднеквадратичная ошибка равна 34362.2778933827
# Квадратный корень из среднеквадратичной ошибки равен 185.37065003226022
# Средняя абсолютная ошибка равна 144.19665221091068
# Коэффициент детерминации равен 0.8431654640899504

# %%
residuals_3 = y_test - predictions_3
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
axes[0].hist(residuals_3, bins=50, edgecolor='black')
axes[0].set_title('Гистограмма распределения остатков')
axes[0].set_xlabel('Остатки')

axes[1].scatter(predictions_3, residuals_3)
axes[1].set_xlabel('Предсказания модели')
axes[1].set_ylabel('Остатки')
axes[1].set_title('Анализ дисперсии')
plt.show()

# %% [markdown]
# **Вывод**
#
# В ходе работы с моделью линейной регрессии №2 можно сделать следующие выводы:
# - Среднеквадратичная ошибка равна 34362;
# - Квадратный корень из среднеквадратичной ошибки равен 185.37;
# - Средняя абсолютная ошибка равна 144.2;
# - Коэффициент детерминации равен 0.84;
# - Гистограмма остатков распределена нормально около нулевого значения;
# - Дисперсия предсказаний постоянна на всех участках.

# %% [markdown]
# ### 5.4 Сравнение моделей

# %%
r2_compared = {1:r2_1, 2:r2_2, 3:r2_3}
residuals_compared = {1:residuals_1.mean(), 2:residuals_2.mean(), 3:residuals_3.mean()}

for number, score in r2_compared.items():
    print(f'Коэффициент детерминации модели №{number} равен {score}')
for number, delta in residuals_compared.items():
    print(f'Средние остатки в модели №{number} равны {delta}')
# Out:
# Коэффициент детерминации модели №1 равен 0.7832029531509055
# Коэффициент детерминации модели №2 равен 0.8347436421181884
# Коэффициент детерминации модели №3 равен 0.8431654640899504
# Средние остатки в модели №1 равны 1.661755003730861
# Средние остатки в модели №2 равны 3.739640079056652
# Средние остатки в модели №3 равны 14.627285574726294

# %% [markdown]
# **Вывод**
#
# На основании сравнения моделей можно заметить:
# - Наилбольший показатель в коэффициенте детерминации (0.84) у модели №3, при этом наибольший показатель по средним остаткам (16.98);
# - Наименьший показатель в коэффициенте детерминации (0.78) у модели №1, но при этом у нее наименьшее среднее по остаткам (1.66);
# - Среднее значение в коэффициенте детерминации (0.83) у модели №2, и также среднее значение по остаткам (3.74).

# %% [markdown]
# ### 5.5 Дополнительные метрики

# %%
metrics_compared = {1:[mse_1, rmse_1, mae_1], 2:[mse_2, rmse_2, mae_2], 3:[mse_3, rmse_3, mae_3]}

for i, (number, metric) in enumerate(metrics_compared.items()):
    print(f'Среднеквадратичная ошибка модели №{number} равна {metric[0]}')
    print(f'Квадратный корень из среднеквадратичной ошибки модели №{number} равен {metric[1]}')
    print(f'Средняя абсолютная ошибка модели №{number} равна {metric[2]}')
    print()
# Out:
# Среднеквадратичная ошибка модели №1 равна 47499.999455259895
# Квадратный корень из среднеквадратичной ошибки модели №1 равен 217.94494592731417
# Средняя абсолютная ошибка модели №1 равна 173.80122314737423
#
# Среднеквадратичная ошибка модели №2 равна 36207.49001635706
# Квадратный корень из среднеквадратичной ошибки модели №2 равен 190.28265821234749
# Средняя абсолютная ошибка модели №2 равна 149.71979977040343
#
# Среднеквадратичная ошибка модели №3 равна 34362.2778933827
# Квадратный корень из среднеквадратичной ошибки модели №3 равен 185.37065003226022
# Средняя абсолютная ошибка модели №3 равна 144.19665221091068

# %% [markdown]
# **Вывод**
#
# В качестве лучшей модели была выбрана модель №3, потому что хоть она и имеет наибольшие остатки, по всем остальным показателям он выигрывает, поэтому дальнейшая работа будет проводиться с ней.

# %%
print(f'Доверительный интервал равен [{np.quantile(predictions_3, 0.025)}, {np.quantile(predictions_3, 0.975)}]')
# Out:
# Доверительный интервал равен [5327.312979915442, 6741.579114709713]

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Здесь все корректно.
# </div>

# %% [markdown]
# ### 5.6 Финальная модель
#
# С помощью лучшей модели спрогнозируйте удой коров, которых фермер хочет купить. Данные о них находятся в датасете cow_buy.csv.
# Добавьте недостающие признаки ЭКЕ (Энергетическая кормовая единица), Сырой протеин, г и СПО (Сахаро-протеиновое соотношение): возьмите из датасета ferma_main.csv средние значения каждого из признаков и увеличьте их на 5%.
# Выполните подготовку данных, аналогичную той, которую делали для тренировочной выборки.
# Получите прогноз удоя коров.

# %%
cow_buy_ml = cow_buy.copy()

mean_values = 1.05 * ferma_main[['эке', 'сырой_протеин', 'спо']].mean()
cow_buy_ml['эке_квад'] = mean_values['эке'] ** 2
cow_buy_ml['сырой_протеин'] = mean_values['сырой_протеин']
cow_buy_ml['спо_кат'] = 1 if mean_values['спо'] >= 0.915 else 0
cow_buy_ml.drop(['текущая_жирность', 'текущий_белок'], axis=1, inplace=True)
cow_buy_ml
display(cow_buy_ml.head())
print(cow_buy_ml.shape)
# Out:
#             порода тип_пастбища порода_папы  имя_папы      возраст  \
# 0   Вис Бик Айдиал    Холмистое      Айдиал  Геркулес  более_2_лет
# 1   Вис Бик Айдиал    Равнинное     Соверин    Буйный  менее_2_лет
# 2  РефлешнСоверинг    Равнинное     Соверин     Барин  более_2_лет
# 3  РефлешнСоверинг    Холмистое      Айдиал    Буйный  более_2_лет
# 4  РефлешнСоверинг    Равнинное      Айдиал    Буйный  более_2_лет
#
#      эке_квад  сырой_протеин  спо_кат
# 0  233.361138    2019.947532        1
# 1  233.361138    2019.947532        1
# 2  233.361138    2019.947532        1
# 3  233.361138    2019.947532        1
# 4  233.361138    2019.947532        1
# (20, 8)

# %%
display(ferma_lr3.head())
print(ferma_lr3.shape)
# Out:
#    удой  сырой_протеин           порода тип_пастбища      возраст  имя_папы  \
# 0  5863           1743   Вис Бик Айдиал    Равнинное  более_2_лет    Буйный
# 1  5529           2138   Вис Бик Айдиал    Равнинное  менее_2_лет  Соловчик
# 2  5810           1854  РефлешнСоверинг    Холмистое  более_2_лет     Барин
# 3  5895           2012  РефлешнСоверинг    Холмистое  более_2_лет    Буйный
# 4  5302           1675   Вис Бик Айдиал    Равнинное  менее_2_лет     Барин
#
#    спо_кат  эке_квад
# 0        0    201.64
# 1        0    163.84
# 2        0    196.00
# 3        0    153.76
# 4        0    163.84
# (623, 8)

# %%
#Подготовка выборок
X_train = ferma_lr3.drop('удой', axis=1)
y_train = ferma_lr3['удой']
X_test = cow_buy_ml

num_col_names = ['сырой_протеин', 'эке_квад']
cat_col_names = ['порода', 'тип_пастбища', 'возраст', 'спо_кат', 'имя_папы']

# %%
X_train_ohe = encoder.fit_transform(X_train[cat_col_names])
X_test_ohe = encoder.transform(X_test[cat_col_names])

encoder_col_names = encoder.get_feature_names()

#Масштабирование количественных признаков
X_train_scaled = scaler.fit_transform(X_train[num_col_names])
X_test_scaled = scaler.transform(X_test[num_col_names])

#Формирование выборок
X_train_ohe = pd.DataFrame(X_train_ohe, columns=encoder_col_names)
X_test_ohe = pd.DataFrame(X_test_ohe, columns=encoder_col_names)

X_train_scaled = pd.DataFrame(X_train_scaled, columns=num_col_names)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=num_col_names)

X_train = pd.concat([X_train_ohe, X_train_scaled], axis=1)
X_test = pd.concat([X_test_ohe, X_test_scaled], axis=1)

# %% [markdown]
#  <div class="alert alert-block alert-danger">
# <h2><s> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# От третьей модели у нас оставалась собственно модель, сохраненная в переменную, скелер и энкодер. То есть, здесь ничего заново обучать не нужно: берем данные, подготавливаем, делаем «трансформ» с помощью скелера и энкодера, а затем «предикт» моделью.
#
# Иначе выходит как если бы мы после каждого запроса к Чатджипити заново обучали всю нейросеть заново. Зачем тратить вычислительные ресурсы?

# %% [markdown]
# <div class="alert alert-info">
# <h5> Комментарий студента </h5>
#
# Это логично🤔. Поправил.
# </div>

# %%
#model_final.fit(X_train, y_train)
predictions_final = model_lr3.predict(X_test)

# %%
cow_buy['предполагаемый_удой'] = predictions_final
cow_buy.sort_values(by='предполагаемый_удой', ascending=False)
# Out:
#              порода тип_пастбища порода_папы  имя_папы  текущая_жирность  \
# 0    Вис Бик Айдиал    Холмистое      Айдиал  Геркулес              3.58
# 6    Вис Бик Айдиал    Холмистое      Айдиал  Геркулес              3.58
# 12   Вис Бик Айдиал    Холмистое      Айдиал  Геркулес              3.68
# 15  РефлешнСоверинг    Холмистое      Айдиал    Буйный              3.40
# 3   РефлешнСоверинг    Холмистое      Айдиал    Буйный              3.40
# 11  РефлешнСоверинг    Равнинное     Соверин  Геркулес              3.73
# 19  РефлешнСоверинг    Равнинное      Айдиал    Буйный              3.64
# 4   РефлешнСоверинг    Равнинное      Айдиал    Буйный              3.64
# 7    Вис Бик Айдиал    Равнинное     Соверин    Буйный              3.57
# 18   Вис Бик Айдиал    Равнинное     Соверин    Буйный              3.34
# 9   РефлешнСоверинг    Холмистое      Айдиал    Буйный              3.40
# 5   РефлешнСоверинг    Равнинное     Соверин  Геркулес              3.63
# ...

# %% [markdown]
# ### 5.7 Вывод
#
# В ходе работы с моделью линейной регрессии можно сделать следующие выводы:
# - Было получено 3 модели и по характеристикам выбрана лучшая;
# - Ее характеристики следующие:
#     - Среднеквадратичная ошибка равна 34362;
#     - Квадратный корень из среднеквадратичной ошибки равен 185.37;
#     - Средняя абсолютная ошибка равна 144.2;
#     - Коэффициент детерминации равен 0.84;
#     - Гистограмма остатков распределена нормально около нулевого значения;
#     - Дисперсия предсказаний постоянна на всех участках.
# - В результате работы модели для прогнозирования удоя можно рекомендовать фермеру любых коров, потому что все их них дадут более 6000 кг молока в год. Для сравнения таблица с отсортированным удоем представлена выше.

# %% [markdown]
# ## 6 Обучение модели логистической регрессии

# %% [markdown]
# ### 6.1 Разработка модели

# %%
ferma_log = ferma_ml.copy(deep=True)
ferma_log['вкус_молока_кат'] = ferma_log['вкус_молока'].apply(lambda x: 1 if x == 'вкусно' else 0)
ferma_log['спо_кат'] = ferma_log['спо'].apply(lambda x: 1 if x >= 0.915 else 0)
ferma_log['эке_квад'] = ferma_log['эке'] ** 2

ferma_log = ferma_log.drop(['id', 'удой', 'вкус_молока', 'эке', 'спо'], axis=1)

ferma_log.head()
# Out:
#    сырой_протеин           порода тип_пастбища порода_папы  жирность  белок  \
# 0           1743   Вис Бик Айдиал    Равнинное      Айдиал      3.58  3.076
# 1           2138   Вис Бик Айдиал    Равнинное     Соверин      3.54  3.079
# 2           1854  РефлешнСоверинг    Холмистое     Соверин      3.59  3.074
# 3           2012  РефлешнСоверинг    Холмистое      Айдиал      3.40  3.075
# 4           1675   Вис Бик Айдиал    Равнинное     Соверин      3.73  3.073
#
#        возраст  вкус_молока_кат  спо_кат  эке_квад
# 0  более_2_лет                1        0    201.64
# 1  менее_2_лет                1        0    163.84
# 2  более_2_лет                0        0    196.00
# 3  более_2_лет                0        0    153.76
# 4  менее_2_лет                1        0    163.84

# %%
#Cоздание константы RANDOM_STATE
RANDOM_STATE = 42
#Подготовка выборок
X = ferma_log.drop('вкус_молока_кат', axis=1)
y = ferma_log['вкус_молока_кат']

X_train, X_valid, y_train, y_valid = train_test_split(X, y, random_state=RANDOM_STATE)

num_col_names = ['сырой_протеин', 'жирность', 'белок','эке_квад']
cat_col_names = ['порода', 'тип_пастбища', 'порода_папы', 'возраст', 'спо_кат']

# %%
encoder = OneHotEncoder(drop='first', sparse=False)
X_train_ohe = encoder.fit_transform(X_train[cat_col_names])
X_valid_ohe = encoder.transform(X_valid[cat_col_names])

encoder_col_names = encoder.get_feature_names()

#Масштабирование количественных признаков
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train[num_col_names])
X_valid_scaled = scaler.transform(X_valid[num_col_names])

#Формирование выборок
X_train_ohe = pd.DataFrame(X_train_ohe, columns=encoder_col_names)
X_valid_ohe = pd.DataFrame(X_valid_ohe, columns=encoder_col_names)

X_train_scaled = pd.DataFrame(X_train_scaled, columns=num_col_names)
X_valid_scaled = pd.DataFrame(X_valid_scaled, columns=num_col_names)

X_train = pd.concat([X_train_ohe, X_train_scaled], axis=1)
X_valid = pd.concat([X_valid_ohe, X_valid_scaled], axis=1)

# %%
clf = LogisticRegression()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_valid)

clf_accuracy = accuracy_score(y_valid, y_pred)
clf_precision = precision_score(y_valid, y_pred)
clf_recall = recall_score(y_valid, y_pred)

print(f'Accuracy равно {clf_accuracy}')
print(f'Precision равно {clf_precision}')
print(f'Recall равно {clf_recall}')
# Out:
# Accuracy равно 0.6217948717948718
# Precision равно 0.625
# Recall равно 0.8045977011494253

# %%
cm = confusion_matrix(y_valid, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues_r')
plt.ylabel('True label')
plt.xlabel('Predicted');

# %% [markdown]
# **Вывод**
#
# В ходе разработки была получена модель со следующими характеристиками:
# - Accuracy равно 0.62;
# - Precision равно 0.625;
# - Recall равно 0.805.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍  Ок
# </div>

# %% [markdown]
# ### 6.2 Анализ модели
#
# Поскольку для фермера наиболее важным фактором является - вкус молока, нельзя чтобы модель предсказала невкусное молоко вкусным. Нельзя допустить ложноположительного ответа, то есть нельзя допустить ошибки первого рода, таким образом необходимо precision свести к максимуму.

# %% [markdown]
#  <div class="alert alert-block alert-danger">
# <h2><s> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Все верно, только описка: `precision свести к минимуму.`
#
# Ложноположительную ошибку − к минимуму, а precision − к максимуму.

# %% [markdown]
# <div class="alert alert-info">
# <h5> Комментарий студента </h5>
#
# Да, так и есть. Видимо заработался.
# </div>

# %%
y_proba = clf.predict_proba(X_valid)[:,1]
data = pd.DataFrame(zip(y_valid, y_proba),
    columns = ['y_valid', 'y_proba']).sort_values(by='y_proba',ascending=False)

data.head()
# Out:
#      y_valid   y_proba
# 32         1  0.855521
# 112        1  0.851525
# 26         1  0.845163
# 142        1  0.844019
# 64         1  0.830481

# %%
thresholds_1 = [round(i,2) for i in np.linspace(0.1,1,num = 20,endpoint=False)]

for i in thresholds_1:
    data['y_pred_'+str(i)] = data['y_proba'].apply(lambda x: 1 if x>=i else 0)

data.sample(5)
# Out:
#      y_valid   y_proba  y_pred_0.1  y_pred_0.15  y_pred_0.19  y_pred_0.24  \
# 88         1  0.469653           1            1            1            1
# 114        1  0.632712           1            1            1            1
# 141        1  0.760819           1            1            1            1
# 64         1  0.830481           1            1            1            1
# 39         0  0.584652           1            1            1            1
#
#      y_pred_0.28  y_pred_0.32  y_pred_0.37  y_pred_0.42  y_pred_0.46  \
# 88             1            1            1            1            1
# 114            1            1            1            1            1
# 141            1            1            1            1            1
# 64             1            1            1            1            1
# 39             1            1            1            1            1
#
#      y_pred_0.5  y_pred_0.55  y_pred_0.6  y_pred_0.64  y_pred_0.68  \
# ...

# %% [markdown]
# Для визуального представления данных построим график с метриками классификации логистической регрессии.

# %%
precision, recall, thresholds = precision_recall_curve(y_valid, y_proba)

plt.figure(figsize=(7,5))
plt.title("Precision-Recall vs Threshold Chart")
plt.plot(thresholds, precision[: -1], "b", label="Precision")
plt.plot(thresholds, recall[: -1], "r", label="Recall")
plt.ylabel("Precision, Recall")
plt.xlabel("Threshold")
plt.legend(loc="lower left")
plt.ylim([0,1.1]);

# %% [markdown]
# Проведем более подробный анализ порогов классификации. Для этого создадим функцию, которая будет выводить таблицу с метриками для различных порогов классификации

# %%
def thresholds_proba(thresholds_list, y_proba_sample, y_sample):
    result_df = pd.DataFrame()
    accuracy = []
    precision = []
    recall = []

    for threshold in thresholds_list:
        y_pred_new_threshold = (y_proba_sample >= threshold).astype(int) 
        accuracy.append(accuracy_score(y_sample, y_pred_new_threshold))
        precision.append(precision_score(y_sample, y_pred_new_threshold, zero_division=1)) 
        recall.append(recall_score(y_sample, y_pred_new_threshold))

    result_df['threshold'] = thresholds_list
    result_df['accuracy'] = accuracy
    result_df['precision'] = precision
    result_df['recall'] = recall
    return result_df

# %%
thresholds_proba(thresholds_1, y_proba, y_valid)
# Out:
#     threshold  accuracy  precision    recall
# 0        0.10  0.557692   0.557692  1.000000
# 1        0.15  0.557692   0.557692  1.000000
# 2        0.19  0.557692   0.557692  1.000000
# 3        0.24  0.557692   0.557692  1.000000
# 4        0.28  0.583333   0.572368  1.000000
# 5        0.32  0.583333   0.574324  0.977011
# 6        0.37  0.583333   0.576389  0.954023
# 7        0.42  0.602564   0.589928  0.942529
# 8        0.46  0.608974   0.604839  0.862069
# 9        0.50  0.621795   0.625000  0.804598
# 10       0.55  0.641026   0.659794  0.735632
# 11       0.60  0.615385   0.670886  0.609195
# 12       0.64  0.608974   0.703125  0.517241
# 13       0.68  0.608974   0.770833  0.425287
# 14       0.73  0.589744   0.925926  0.287356
# 15       0.77  0.551282   1.000000  0.195402
# 16       0.82  0.493590   1.000000  0.091954
# 17       0.86  0.442308   1.000000  0.000000
# 18       0.91  0.442308   1.000000  0.000000
# 19       0.96  0.442308   1.000000  0.000000

# %% [markdown]
# Можно было бы взять порог, равный 0.77, он был бы идеальным для нас. Однако при этом точность определения падает. Изучим более подробно диапазон [0.68-0.77].

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2><s> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# В терминах бизнес задачи, нам все равно, сколько вкусных коров мы не купим, но нам критически важно, чтобы те коровы, которых мы купили, исключительно давали вкусное молоко.
#
# Фермер не хочет рисковать и хочет купить коров, которые будут давать вкусное молоко.
#
# В задании сказано свести критичную ошибку к нулю.
#
# ***
#
# Полезно оставить 2-3 ложноположительных ошибки на случай технических ошибок в определении таргета (не будем отлавливать каждую «невкусную» корову, вполне возможно ее такой назвали ошибочно).
#
# Важно повысить порог.

# %% [markdown]
# <div class="alert alert-info">
# <h5> Комментарий студента </h5>
#
# Повысил порог, ошибок первого рода не стало.
# </div>

# %%
thresholds_2 = [round(i,2) for i in np.linspace(0.68,0.78,num = 10,endpoint=False)]
thresholds_proba(thresholds_2, y_proba, y_valid)
# Out:
#    threshold  accuracy  precision    recall
# 0       0.68  0.608974   0.770833  0.425287
# 1       0.69  0.615385   0.800000  0.413793
# 2       0.70  0.589744   0.810811  0.344828
# 3       0.71  0.576923   0.800000  0.321839
# 4       0.72  0.596154   0.875000  0.321839
# 5       0.73  0.589744   0.925926  0.287356
# 6       0.74  0.583333   0.923077  0.275862
# 7       0.75  0.576923   0.920000  0.264368
# 8       0.76  0.570513   0.954545  0.241379
# 9       0.77  0.551282   1.000000  0.195402

# %% [markdown]
# Accuracy близкая к максимальной есть при пороге 0.69, при этом мы повысим precision до 0.8. Выберем его в качестве основного для дальнейшей работы.

# %%
SELECT_THRESHOLD = 0.77

y_pred_threshold = (clf.predict_proba(X_valid)[:, 1] >= SELECT_THRESHOLD).astype(int)

cm = confusion_matrix(y_valid, y_pred_threshold)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues_r')
plt.ylabel('True label')
plt.xlabel('Predicted');

# %% [markdown]
# **Вывод**
#
# При выбранном пороге (0.77) удалось снизить количество ошибок первого рода (FP) с 42 до 0.

# %% [markdown]
# ### 6.3 Финальная модель

# %%
cow_buy_ml_2 = cow_buy.copy(deep=True)

cow_buy_ml_2['эке_квад'] = mean_values['эке'] ** 2
cow_buy_ml_2['сырой_протеин'] = mean_values['сырой_протеин']
cow_buy_ml_2['спо_кат'] = 1 if mean_values['спо'] >= 0.915 else 0

cow_buy_ml_2.rename(columns={'текущая_жирность': 'жирность', 'текущий_белок': 'белок'}, inplace=True)
cow_buy_ml_2.drop(['имя_папы'], axis=1, inplace=True)

display(cow_buy_ml_2.head())
print(cow_buy_ml_2.shape)
# Out:
#             порода тип_пастбища порода_папы  жирность  белок      возраст  \
# 0   Вис Бик Айдиал    Холмистое      Айдиал      3.58  3.076  более_2_лет
# 1   Вис Бик Айдиал    Равнинное     Соверин      3.54  3.081  менее_2_лет
# 2  РефлешнСоверинг    Равнинное     Соверин      3.59  3.074  более_2_лет
# 3  РефлешнСоверинг    Холмистое      Айдиал      3.40  3.061  более_2_лет
# 4  РефлешнСоверинг    Равнинное      Айдиал      3.64  3.074  более_2_лет
#
#    предполагаемый_удой    эке_квад  сырой_протеин  спо_кат
# 0          6615.101031  233.361138    2019.947532        1
# 1          6317.274363  233.361138    2019.947532        1
# 2          6287.758049  233.361138    2019.947532        1
# 3          6605.169186  233.361138    2019.947532        1
# 4          6552.792114  233.361138    2019.947532        1
# (20, 10)

# %%
display(ferma_log.head())
print(ferma_log.shape)
# Out:
#    сырой_протеин           порода тип_пастбища порода_папы  жирность  белок  \
# 0           1743   Вис Бик Айдиал    Равнинное      Айдиал      3.58  3.076
# 1           2138   Вис Бик Айдиал    Равнинное     Соверин      3.54  3.079
# 2           1854  РефлешнСоверинг    Холмистое     Соверин      3.59  3.074
# 3           2012  РефлешнСоверинг    Холмистое      Айдиал      3.40  3.075
# 4           1675   Вис Бик Айдиал    Равнинное     Соверин      3.73  3.073
#
#        возраст  вкус_молока_кат  спо_кат  эке_квад
# 0  более_2_лет                1        0    201.64
# 1  менее_2_лет                1        0    163.84
# 2  более_2_лет                0        0    196.00
# 3  более_2_лет                0        0    153.76
# 4  менее_2_лет                1        0    163.84
# (623, 10)

# %%
#Подготовка выборок
X_train = ferma_log.drop('вкус_молока_кат', axis=1)
y_train = ferma_log['вкус_молока_кат']
X_test = cow_buy_ml_2

num_col_names = ['сырой_протеин', 'жирность', 'белок', 'эке_квад']
cat_col_names = ['порода', 'тип_пастбища', 'порода_папы', 'возраст', 'спо_кат']

# %%
X_train_ohe = encoder.fit_transform(X_train[cat_col_names])
X_test_ohe = encoder.transform(X_test[cat_col_names])

encoder_col_names = encoder.get_feature_names()

#Масштабирование количественных признаков
X_train_scaled = scaler.fit_transform(X_train[num_col_names])
X_test_scaled = scaler.transform(X_test[num_col_names])

#Формирование выборок
X_train_ohe = pd.DataFrame(X_train_ohe, columns=encoder_col_names)
X_test_ohe = pd.DataFrame(X_test_ohe, columns=encoder_col_names)

X_train_scaled = pd.DataFrame(X_train_scaled, columns=num_col_names)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=num_col_names)

X_train = pd.concat([X_train_ohe, X_train_scaled], axis=1)
X_test = pd.concat([X_test_ohe, X_test_scaled], axis=1)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2><s> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Здесь также стоит использовать ранее обученную модель. Не стоит дублировать обучение. Здесь на самом деле ровно одинаковая модель, делаем одно и то же.
#
# Важно использовать готовую модель, скелер и энкодер, обученные чуть выше в проекте.

# %% [markdown]
# <div class="alert alert-info">
# <h5> Комментарий студента </h5>
#
# Поправил. В будущем уже буду более внимательно относиться к организации кода и обучения.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Дальше будем проходить пайплайны, там эта проблема будет решаться иначе.
# </div>

# %%
y_proba_final = clf.predict_proba(X_test)[:, 1]
y_pred_final = (y_proba_final > SELECT_THRESHOLD).astype(int)

cow_buy['ожидаемый_вкус_молока'] = y_pred_final
cow_buy['ожидаемый_вкус_молока'] = cow_buy['ожидаемый_вкус_молока'].apply(lambda x: 'вкусно' if x == 1 else 'не вкусно')

cow_buy_sum = cow_buy.query('ожидаемый_вкус_молока == "вкусно"').sort_values(by='предполагаемый_удой', ascending=True)

cow_buy.sort_values(by='ожидаемый_вкус_молока', ascending=True)
# Out:
#              порода тип_пастбища порода_папы  имя_папы  текущая_жирность  \
# 0    Вис Бик Айдиал    Холмистое      Айдиал  Геркулес              3.58
# 17  РефлешнСоверинг    Равнинное     Соверин  Геркулес              3.77
# 16   Вис Бик Айдиал    Холмистое     Соверин  Соловчик              3.73
# 15  РефлешнСоверинг    Холмистое      Айдиал    Буйный              3.40
# 14  РефлешнСоверинг    Равнинное     Соверин     Барин              3.59
# 13   Вис Бик Айдиал    Холмистое     Соверин     Барин              3.42
# 12   Вис Бик Айдиал    Холмистое      Айдиал  Геркулес              3.68
# 11  РефлешнСоверинг    Равнинное     Соверин  Геркулес              3.73
# 10   Вис Бик Айдиал    Холмистое     Соверин  Соловчик              3.73
# 9   РефлешнСоверинг    Холмистое      Айдиал    Буйный              3.40
# 8   РефлешнСоверинг    Равнинное     Соверин     Барин              3.59
# 7    Вис Бик Айдиал    Равнинное     Соверин    Буйный              3.57
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Всё верно по коду, нужно будет уточнить по результату с более высоким порогом. Может оказаться, что ни одна из коров не подходит. Это нормально. Пока следуем ТЗ.
#
# Альтернативно можно предложить заказчику сразу ответ и по более низкому порогу (по твоему текущему) на случай, если он решит все-таки купить каких-то коров.
#
# Однако базово нужно строго выполнить его задание.
#
# </div>

# %% [markdown]
# ### 6.4 Вывод
#
# В ходе работы с моделью логистической регрессии можно сделать следующие выводы:
# - Было получена модель и выбран оптимальный порог классификации 0.77:
#     - Accuracy равна 0.551;
#     - Precision равна 1.0;
#     - Recall равна 0.195.
# - В результате работы модели для прогнозирования вкуса молока нельзя рекомендовать ни одну корову;
# - Альтернативным вариантом можно снизить порог классификации 0.69:
#     - При таком пороге характеристики модели следующие:
#     - Accuracy равна 0.615;
#     - Precision равна 0.8;
#     - Recall равна 0.413793.

# %% [markdown]
# ## 7 Итоговые выводы

# %% [markdown]
# В ходе проведенного исследования был проделан следующий ряд работ и сделаны следующие выводы:
#
#
# 1. Открыт и изучен файл
#     - Датасет `ferma_main`:
#         - Всего в датасете 634 строки и 12 столбцов;
#     - Датасет `ferma_dad`:
#         - Всего в датасете 629 строк и 2 столбца;
#     - Датасет `cow_buy`:
#         - Всего в датасете 20 строк и 7 столбцов;
#     - Данные были признаны пригодными для исследования.
#
#
# 2. Проведена предобработка данных:
#     - Датасет `ferma_main`:
#         - Названия столбцов приведены к общему виду;
#         - Удалены явные дубликаты в данных (вероятно, из-за технической ошибки);
#         - Обработаны неявные дубликаты (вероятно, человеческий фактор);
#         - Удален вброс в данных признака `удой`.
#     - Датасет `ferma_dad`:
#         - Названия столбцов приведены к общему виду;
#         - Данные проверены на дубликаты, выявлено не было.
#     - Датасет `cow_buy`:
#         - Названия столбцов приведены к общему виду.
#     - Датасет `ferma_full`:
#         - Путем объединения `ferma_main` и `ferma_dad` был получен датасет `ferma_full`.
#
#
# 3. Проведен исследовательский анализ данных:
#     - Количественные признаки:
#         - Признак `удой` распределен нормально, имеет среднее значение около 6100 кг;
#         - Признак `эке`распределен нормально, выбросов не имеет, среднее значение около 14.5;
#         - Признак `сырой_протеин` не распределен нормально, вероятно, это связано со спецификой переменной. Выбросов не имеет, среднее значение около 1900 г.
#         - Признак `спо` не имеет нормального распределения, вероятно, из-за специфики значения. Выбросов не имеет, среднее значение 0.93.
#         - Признак `жирность`. Наблюдаются выбросы в значениях жирности меньше 3.4, их доля от общего числа составляет почти 14 процентов. Выбросы так же имеют реалистичные значения, такая жирность вполне может быть в зависимости от корма. Поскольку количество выбросов велико для выборки и значения реалистичны, данные оставляем.
#         - Признак `белок` имеет нормальное распределение, имеет выбросы, которые так же можно объяснить кормом и условиями содержания коровы, но поскольку количество выбросов невелико в соотнешении со всей выборкой, можно избавиться от этих выбросов.
#     - Категориальные признаки:
#         - Признаки `порода`, `тип_пастбища`, `порода_папы` и `вкус_молока` имеют близкое отношение 1:1;
#         - Признак `возраст` распределяется на более_2_лет (82.5%) и менее_2_лет (17.5%);
#         - Признак `имя_папы` показывает самых многодетных отцов: Барина (38.52%) и Буйного (34.03%).
#
#
# 4. Проведен корреляционный анализ:
#     - `эке` имеет высокую прямую корреляцию, равную 0.72. Причем вне зависимости от породы график рассеения имеет общий тренд.
#     - `сырой_протеин`имеет умеренную прямую корреляцию, равную 0.47. Причем вне зависимости от породы график рассеения имеет общий тренд.
#     - `спо` имеет заметную прямую корреляцию, равную 0.66. Распредление точек на графике рассеяния примерно одинаковое для обеих пород.
#     - `жирность` имеет высокую прямую корреляцию, равную 0.71. Разброс на графиках рассеяния достаточно большой, но наблюдаются наиболее плотные скопления точек при значениях 3.6 и 3.7.
#     - `белок` имеет слабую прямую корреляцию, равную 0.21. Значение белка в молоке больше у породы Вис Бик Айдиал, но явно выраженной зависимости количества удоя от значения белка не наблюдается.
#     - Между входными и целевым признаками наблюдается явная линейная связь.
#     - Значимых нелинейных зависимостей между входными и целевым признаками не обнаружено, разве что `спо`, но незначительно.
#     - Мультиколлинеарность обнаружена между признаками `порода_папы` и `имя_папы`. Удалим столбец `имя папы`, напомню, что объединяли мы его для более комфортной работы при предобработке данных.
#
#
# 5. Обучена модель линейной регрессии:
#     - Было получено 3 модели и по характеристикам выбрана лучшая;
#     - Ее характеристики следующие:
#         - Среднеквадратичная ошибка равна 34362;
#         - Квадратный корень из среднеквадратичной ошибки равен 185.37;
#         - Средняя абсолютная ошибка равна 144.2;
#         - Коэффициент детерминации равен 0.84;
#         - Гистограмма остатков распределена нормально около нулевого значения;
#         - Дисперсия предсказаний постоянна на всех участках.
#     - В результате работы модели для прогнозирования удоя можно рекомендовать фермеру любых коров, потому что все их них дадут более 6000 кг молока в год.
#
#
# 6. Обучена модель логистической регресии:
#     - Была получена модель и выбран оптимальный порог классификации 0.77:
#         - Accuracy равна 0.551;
#         - Precision равна 1.0;
#         - Recall равна 0.195.
#     - В результате работы такой модели для прогнозирования вкуса молока нельзя рекомендовать ни одну корову;
#     - Альтернативным вариантом можно снизить порог классификации 0.69:
#         - При таком пороге характеристики модели следующие:
#         - Accuracy равна 0.615;
#         - Precision равна 0.8;
#         - Recall равна 0.413793.
#     - В результате работы альтернативной модели для прогнозирования вкуса молока можно рекомендовать коров с id, равным 0, 6, 9, 16.
#
#
# 7. Итоговый вывод:
#     - Согласно разработанным моделям линейной и логистической регрессий, к покупке рекомндованы коровы, представленные в таблице ниже.

# %%
cow_buy.sort_values(by=['ожидаемый_вкус_молока', 'предполагаемый_удой'], ascending=[True, False])
# Out:
#              порода тип_пастбища порода_папы  имя_папы  текущая_жирность  \
# 0    Вис Бик Айдиал    Холмистое      Айдиал  Геркулес              3.58
# 6    Вис Бик Айдиал    Холмистое      Айдиал  Геркулес              3.58
# 12   Вис Бик Айдиал    Холмистое      Айдиал  Геркулес              3.68
# 3   РефлешнСоверинг    Холмистое      Айдиал    Буйный              3.40
# 15  РефлешнСоверинг    Холмистое      Айдиал    Буйный              3.40
# 11  РефлешнСоверинг    Равнинное     Соверин  Геркулес              3.73
# 4   РефлешнСоверинг    Равнинное      Айдиал    Буйный              3.64
# 19  РефлешнСоверинг    Равнинное      Айдиал    Буйный              3.64
# 7    Вис Бик Айдиал    Равнинное     Соверин    Буйный              3.57
# 18   Вис Бик Айдиал    Равнинное     Соверин    Буйный              3.34
# 9   РефлешнСоверинг    Холмистое      Айдиал    Буйный              3.40
# 5   РефлешнСоверинг    Равнинное     Соверин  Геркулес              3.63
# ...

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# В задании проекта нас также просят здесь указать, как можно еще улучшить качество моделей. Также есть вопросы и по метрикам, важно их не игнорировать.
#
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту**
#
# Спасибо за твой проект! Работа требовала большой концентрации внимания, наблюдательности и нахождения в контексте задачи. С этим все отлично.
#
#
# **Отмечу положительные моменты проекта🚀**
#
# * Хорошая структура проекта.
# * Внимательная предобработка и подготовка признаков.
# * Хорошие решения по коду
#
# **На что стоит обратить внимание🤔**
#
# * Важно использовать только корректный подход для замера корреляции (желтый комментарий).
# * Необходимо уточнить по нелинейности признаков (желтый комментарий).
# * Необходимо убрать дублирование обучения модели при предсказании. Здесь уже используем готовые модель, скелер и энкодер.
# * Важно уточнить и применить порог для предсказания вкуса молока. Следуем строгому ТЗ.
# * Эти и остальные замечания я также написал по ходу проекта.
#
# **Желаю удачи и жду твой проект на повторное ревью!**😉
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h5> Комментарий студента </h5>
#
# Еще такой вопрос по органиазции проектов. В прошлых проектах была автоматическая нумерация заголовков. Как можно сделать такую же автоматическую с нуля? Все что нашел, это только содержание с anchor.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# Честно говоря, про этот момент не знаю. Насколько помню, раньше можно было просто делать заголовки, и они автоматически нумеровались и добавлялись в содержание проекта.
#
# Если не срабатывает в такой реализации, то не знаю решений.
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Комментарий ко второй проверке**
#
# Спасибо за доработку. Критичных комментариев нет.
#
# Если что-то пропустил или остались вопросы, напиши в телеграм @kriill
#
# Желаю удачи в дальнейшей учебе!
#
# </div>
